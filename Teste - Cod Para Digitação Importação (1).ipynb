# %% [markdown]
# Leitura Cabeçalho

# %%
# !pip install pyautogui

# %%
import datetime
import pyautogui
import pandas as pd

df = pd.read_excel('Compra_2024_05_Conexão_Matriz.xlsx')
display(df)

import pandas as pd

#Guarda a quantidade de fornecedores, sem repetição
fornecedores = []

#Armazena as quantidades sem os Zeros.
quantidades = []

#Chegada
chegada = []

#Totais Fornecedores
Quantidade_Totais_Fornecedores = []

#Lendo somente a coluna onde estão os fornecedores.
coluna_fornecedor = df.iloc[:, 14]



####################################
#LENDO APENAS A COLUNA QUANTIDADE
####################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada

coluna_desejada = "Comprar" # Substitua 'Nome_da_Coluna' pelo nome da sua coluna

#Armazena a quantidade com os Zeros.
coluna_quantidades = dados[coluna_desejada]



######################################
#TIRANDO OS ZEROS DAS QUANTIDADES LIDAS
######################################



for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        quantidades.append(coluna_quantidades[c])


        
#################################        
#LENDO CHEGADA
#################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Chegada Prevista"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_chegada = dados[coluna_desejada]

chegada_total = []


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        chegada_total.append(int(coluna_chegada[c]))                

            
            
######################################       
#LENDO APENAS A COLUNA "FORNECEDOR".
######################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Fornecedor"  #Substituir 'Nome_da_Coluna' pelo nome da coluna da planilha.

coluna_fornecedor = dados[coluna_desejada]



#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan e previsão de chegada. sem repetição 


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        if coluna_fornecedor[c] not in fornecedores:
            
            fornecedores.append(coluna_fornecedor[c]) 
            chegada.append(int(coluna_chegada[c]))
            
            
#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan. com repetições


fornecedores_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        fornecedores_total.append(coluna_fornecedor[c])



##################################
#LENDO OS CÓDIGOS
##################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Referência"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_codigos = dados[coluna_desejada]

codigos_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        codigos_total.append(coluna_codigos[c])
        
        
        
############################################################################################################



valores = []

pyautogui.sleep(5)

#Definando TOP:
pyautogui.sleep(3)
pyautogui.click(2377,140)
pyautogui.sleep(3)
pyautogui.click(2360,191)
pyautogui.sleep(3)
pyautogui.typewrite("109")
pyautogui.sleep(3)
pyautogui.press('\n')
pyautogui.sleep(3)
pyautogui.click(2484,237)
pyautogui.click(2484,237)
pyautogui.sleep(30)

#Alterando Tela:
pyautogui.click(3814,76)
pyautogui.sleep(1)
pyautogui.click(3586,325)
pyautogui.sleep(1)
pyautogui.click(2685,474)
pyautogui.sleep(1)
pyautogui.click(2978,688)
pyautogui.sleep(30)

pyautogui.sleep(15)

for c in range(len(fornecedores)):
        
        #Inserindo Parceiro: 
        pyautogui.sleep(3)
        pyautogui.click(2210,255)
        pyautogui.sleep(2)  
        pyautogui.click(2464,352)
        pyautogui.sleep(2) 
        pyautogui.typewrite(str(fornecedores[c]))
        pyautogui.press('\n')
        pyautogui.sleep(5)
        pyautogui.click(2566,412)
        pyautogui.click(2566,412)
        
        #PREV. CHEGADA
        pyautogui.sleep(1)
        pyautogui.click(2115,307)
        pyautogui.click(2115,307)
        pyautogui.sleep(1)
        pyautogui.typewrite("01/")
        pyautogui.sleep(1)
        pyautogui.typewrite(str(chegada[c])) 
        pyautogui.sleep(1)
        pyautogui.typewrite("/2025")
        pyautogui.sleep(1)
        
        #PRONTO FABRICA
        data_atual = datetime.date.today()
        data_nova = data_atual + datetime.timedelta(days=60)
        data_atual_formatada = data_atual.strftime("%d/%m/%Y")
        data_nova_formatada = data_nova.strftime("%d/%m/%Y")
        pyautogui.sleep(1)
        pyautogui.click(2112,331)
        pyautogui.sleep(1)
        pyautogui.typewrite(str(data_nova_formatada))

        #DEFININDO MOEDA
        pyautogui.sleep(2)
        pyautogui.click(2467,408)
        pyautogui.sleep(15)
        pyautogui.click(2617,432)
        pyautogui.sleep(2)
        pyautogui.click(3257,828)

        #COMPRADOR
        pyautogui.sleep(2)
        pyautogui.click(2163,458)
        pyautogui.sleep(2)
        pyautogui.typewrite("232")
        
        #TIPO DE TRANSPORTE
        pyautogui.sleep(2)
        pyautogui.click(2396,557)
        #pyautogui.sleep(2)
        #pyautogui.typewrite("Marítima")
        pyautogui.sleep(3)
        #pyautogui.press('\n')
        pyautogui.click(2225,606)
    
        
        #CONFIRMA
        pyautogui.sleep(2)
        pyautogui.click(2000,112)
        pyautogui.sleep(3)
        
        #EXCLUINDO ITEM ADICIONADO AUTOMATICAMENTE
        pyautogui.click(2816,252)
        pyautogui.sleep(2)
        
        #NOVO ITEM
        pyautogui.click(2731,256)
        pyautogui.sleep(2)
        
        pyautogui.sleep(8)
        
        print(fornecedores[c])
        
        x_cod = 2674
        y_cod = 308
        
        x_qtd = 2794
        y_qtd = 304
        
        x_cod_Limite_Tela = 2693 
        y_cod_Limite_Tela = 609
             
        x_qtd_Limite_Tela = 2796
        y_qtd_Limite_Tela = 606
        
        repeticao = 0
        Soma_Quatidades = 0
           
        for i in range(len(fornecedores_total)):
            
            if repeticao < 15:
            
                if fornecedores_total[i] == fornecedores[c]:  
                    
                    #Inserindo Código:
                    pyautogui.click(x_cod,y_cod)
                    pyautogui.sleep(4)
                    pyautogui.typewrite(str(codigos_total[i]))
                    pyautogui.sleep(3)
                    
                    #Inserindo Quantidade:
                    pyautogui.click(x_qtd,y_qtd)
                    pyautogui.sleep(3)
                    pyautogui.typewrite(str(int(quantidades[i])))
                    pyautogui.sleep(3)
                    
                    #Confirmando Item:
                    pyautogui.click(2742,250)
                    pyautogui.click(2742,250)
                    pyautogui.sleep(8)
                    
                    #Novo Item
                    pyautogui.click(2731,256)
                    pyautogui.sleep(2)
                    
                    #Soma dos valores nas coordenadas para que que o mouse realize o deslocamento para o próximo 
                    #campo na proxima repetição.

                    y_cod += 20
                    y_qtd += 20
                    
                    Soma_Quatidades += quantidades[i]
                    
                    repeticao += 1
                    
            else:
                
                 if fornecedores_total[i] == fornecedores[c]:     
                    
                    #Inserindo Código:
                    pyautogui.click(x_cod_Limite_Tela,y_cod_Limite_Tela)
                    pyautogui.sleep(3) 
                    pyautogui.typewrite(str(codigos_total[i]))
                    pyautogui.sleep(3)
                    
                    #Inserindo Quantidade:
                    pyautogui.click(x_qtd_Limite_Tela,y_qtd_Limite_Tela)
                    pyautogui.sleep(3)
                    pyautogui.typewrite(str(int(quantidades[i])))
                    pyautogui.sleep(3)
                    
                    #Confirmando Item:
                    pyautogui.click(2742,250)
                    pyautogui.click(2742,250)
                    pyautogui.sleep(8)
                    
                    #Novo Item
                    pyautogui.click(2731,256)
                    pyautogui.sleep(2)
                    
                    Soma_Quatidades += quantidades[i]
                    
        
        #Novo pedido
        pyautogui.click(1990,115)
        pyautogui.sleep(2)
        pyautogui.click(2748,621)
        
        #Definando TOP:
        pyautogui.sleep(3)
        pyautogui.click(2162,357)
        pyautogui.sleep(3)
        pyautogui.typewrite("109")
        pyautogui.sleep(3)
# Out:
#      Unnamed: 0  Unnamed: 1               Unnamed: 2  Unnamed: 3  \
# 0           NaN         NaN                      NaN         NaN
# 1           NaN         NaN                      NaN         NaN
# 2           NaN  Referência      Descrição (Produto)         1.0
# 3           NaN    DS300002  COPINHO/CLIP  8   (ACO)     79550.0
# 4           NaN    DS300003   COPINHO/CLIP  10 (ACO)     53103.0
# ..          ...         ...                      ...         ...
# 236         NaN         NaN                      NaN         NaN
# 237         NaN         NaN                      NaN         NaN
# 238         NaN         NaN                      NaN         NaN
# 239         NaN         NaN                      NaN         NaN
# 240         NaN         NaN                      NaN         NaN
#
#            Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7  \
# 0                 NaN        NaN        NaN                 NaN
# ...

# %% [markdown]
# Importação das Bibliotecas

# %%
print(len(fornecedores_total))
print(fornecedores_total)
print(len(quantidades))
print(quantidades)
print(len(codigos_total))
print(codigos_total)
print(len(chegada_total))
print(chegada_total)
# Out:
# 52
# ...

# %%
import datetime
import pyautogui
import pandas as pd

df = pd.read_excel('Compra_2024_05_Conexão_Matriz.xlsx')
display(df)

import pandas as pd

#Guarda a quantidade de fornecedores, sem repetição
fornecedores = []

#Armazena as quantidades sem os Zeros.
quantidades = []

#Chegada
chegada = []

#Totais Fornecedores
Quantidade_Totais_Fornecedores = []

#Lendo somente a coluna onde estão os fornecedores.
coluna_fornecedor = df.iloc[:, 14]





####################################
#LENDO APENAS A COLUNA QUANTIDADE
####################################




# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada

coluna_desejada = "Comprar" # Substitua 'Nome_da_Coluna' pelo nome da sua coluna

#Armazena a quantidade com os Zeros.
coluna_quantidades = dados[coluna_desejada]





######################################
#TIRANDO OS ZEROS DAS QUANTIDADES LIDAS
######################################




for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        quantidades.append(coluna_quantidades[c])


        
#################################        
#LENDO CHEGADA
#################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Chegada Prevista"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_chegada = dados[coluna_desejada]

chegada_total = []


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        chegada_total.append(int(coluna_chegada[c]))
                

            
            
######################################       
#LENDO APENAS A COLUNA "FORNECEDOR".
######################################




# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Fornecedor"  #Substituir 'Nome_da_Coluna' pelo nome da coluna da planilha.

coluna_fornecedor = dados[coluna_desejada]



#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan. sem repetição.


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        if coluna_fornecedor[c] not in fornecedores:
            
            fornecedores.append(coluna_fornecedor[c]) 
            chegada.append(coluna_chegada[c])
            
            
#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan. com repetições


fornecedores_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        fornecedores_total.append(coluna_fornecedor[c])

            
 



 ##################################
#LENDO OS CÓDIGOS
##################################
 




# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'Compra_2024_05_Conexão_Matriz.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Referência"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_codigos = dados[coluna_desejada]

codigos_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        codigos_total.append(coluna_codigos[c])
        
        
        
        
#print(len(fornecedores_total))
#print(fornecedores_total)
print(len(quantidades))
print(quantidades)
#print(len(codigos_total))
#print(codigos_total)
#print(len(chegada_total))
#print(chegada_total)
print(len(fornecedores))
print(fornecedores)
print(len(chegada))
print(chegada)
#print(coluna_chegada)
# Out:
#      Unnamed: 0  Unnamed: 1               Unnamed: 2  Unnamed: 3  \
# 0           NaN         NaN                      NaN         NaN
# 1           NaN         NaN                      NaN         NaN
# 2           NaN  Referência      Descrição (Produto)         1.0
# 3           NaN    DS300002  COPINHO/CLIP  8   (ACO)     79550.0
# 4           NaN    DS300003   COPINHO/CLIP  10 (ACO)     53103.0
# ..          ...         ...                      ...         ...
# 236         NaN         NaN                      NaN         NaN
# 237         NaN         NaN                      NaN         NaN
# 238         NaN         NaN                      NaN         NaN
# 239         NaN         NaN                      NaN         NaN
# 240         NaN         NaN                      NaN         NaN
#
#            Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7  \
# 0                 NaN        NaN        NaN                 NaN
# ...

# %% [markdown]
# #####
